# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd

# %%
link='https://books.toscrape.com/'

# %%
for j in range(1,50):
    link="https://books.toscrape.com/catalogue/page-"+str(j)+".html"
    res=r.get(link)
    Soup=BeautifulSoup(res.text,'html.parser')
    for i in Soup.find_all('li',class_="col-xs-6 col-sm-4 col-md-3 col-lg-3"):
    
        
        book_link=link+i.find_all('a')[-1].get('href')
        name=i.find_all('a')[-1].get('title')
        img=("https://books.toscrape.com/"+i.find('img').get('src'))
        rating=i.find('p').get('class')
        price=i.find('p',class_='price_color').text
        availity=i.find('p',class_='instock availability').text.strip()
        data.append([book_link,name,img,rating,price,availity])

# %%
df=pd.DataFrame(data,columns=['book_link','name','img','rating','price','availty'])
df.to_csv("book.csv",index=0)
df
# Out:
#                                               book_link  \
# 0     https://books.toscrape.com/catalogue/a-light-i...
# 1     https://books.toscrape.com/catalogue/tipping-t...
# 2     https://books.toscrape.com/catalogue/soumissio...
# 3     https://books.toscrape.com/catalogue/sharp-obj...
# 4     https://books.toscrape.com/catalogue/sapiens-a...
# ...                                                 ...
# 1475  https://books.toscrape.com/catalogue/page-49.h...
# 1476  https://books.toscrape.com/catalogue/page-49.h...
# 1477  https://books.toscrape.com/catalogue/page-49.h...
# 1478  https://books.toscrape.com/catalogue/page-49.h...
# 1479  https://books.toscrape.com/catalogue/page-49.h...
#
#                                                    name  \
# 0                                  A Light in the Attic
# 1                                    Tipping the Velvet
# 2                                            Soumission
# 3                                         Sharp Objects
# ...

# %%
df=pd.read_csv('book.csv')
del df['img']
del df['rating']

# %%
j=0
for i in df.values:
    
    print(i)
    res=r.get(i[0])
    soup=BeautifulSoup(res.text,'html.parser')
#     name=i[1]+"txt"
    
#     fd=open(name,'w')
#     fd.write(i[1]+"\n")
#     fd.write(i[2]+"\n")
#     fd.write(i[3]+"\n")
#     fd.write(soup.find(p))
    ans=soup.find_all('p')
    print(ans)
    j=j+1
    print("___"*30)
# Out:
# ['https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'
#  'A Light in the Attic' 'Â£51.77' 'In stock']
# [<p class="price_color">Â£51.77</p>, <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock (22 available)
#
# </p>, <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <!-- <small><a href="/catalogue/a-light-in-the-attic_1000/reviews/">
#
#
#                     0 customer reviews
#
#         </a></small>
#          -->
#
#
# <!--
#     <a id="write_review" href="/catalogue/a-light-in-the-attic_1000/reviews/add/#addreview" class="btn btn-success btn-sm">
#         Write a review
#     </a>
#
# ...
